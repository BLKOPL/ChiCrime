# %%
#!pip install pygeocoder

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gmaps
import pygeocoder as Geocoder
import geocoder
import json
import pprint


# Google developer API key

#from config import gkey

# Configure gmaps


# File to Load
crimes_data = "Input/crime_data.csv"

# Read the Crimes Data
crimes_data = pd.read_csv(crimes_data)


# Display the data table for preview
crimes_data.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
location_df = pd.DataFrame(crimes_data)
cols = [-1,-3,-2,]
location_df = location_df[location_df.columns[cols]]
location_df.head(10)
# Out:
#                         Location   Latitude  Longitude
# 0  (41.891398861, -87.744384567)  41.891399 -87.744385
# 1  (41.773371528, -87.665319468)  41.773372 -87.665319
# 2   (41.81386068, -87.596642837)  41.813861 -87.596643
# 3  (41.800802415, -87.622619343)  41.800802 -87.622619
# 4  (41.878064761, -87.743354013)  41.878065 -87.743354
# 5  (41.805443345, -87.604283976)  41.805443 -87.604284
# 6  (41.766402779, -87.649296123)  41.766403 -87.649296
# 7  (41.817552577, -87.619818523)  41.817553 -87.619819
# 8  (41.828138428, -87.672782106)  41.828138 -87.672782
# 9   (41.71745472, -87.617663257)  41.717455 -87.617663

# %%
# 1.Convert longitude and latitude to a location
#results = Geocoder.reverse_geocode(location_df['latitude'][0], location_df['longitude'][0])

results = geocoder.google([location_df['Latitude'][0], location_df['Longitude'][0]], method='reverse')  # lat and lon you've extracted already, but maybe you'll still need to cast them to float.

resp = results.geojson

#json.loads(resp)

resp
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'accuracy': 'ROOFTOP',
#     'address': '4712 W Ohio St, Chicago, IL 60644, USA',
#     'bbox': [-87.74569068029152,
#      41.89024061970849,
#      -87.74299271970851,
#      41.89293858029149],
#     'city': 'Chicago',
#     'confidence': 9,
#     'country': 'US',
#     'county': 'Cook County',
#     'housenumber': '4712',
#     'lat': 41.8915896,
#     'lng': -87.7443417,
#     'neighborhood': 'Austin',
#     'ok': True,
#     'place': 'ChIJ2XGAii4zDogRo-7hng7IdtM',
#     'postal': '60644',
#     'quality': 'street_address',
#     'raw': {'address_components': [{'long_name': '4712',
#        'short_name': '4712',
#        'types': ['street_number']},
#       {'long_name': 'West Ohio Street',
#        'short_name': 'W Ohio St',
#        'types': ['route']},
#       {'long_name': 'Austin',
#        'short_name': 'Austin',
#        'types': ['neighborhood', 'political']},
# ...

# %%
resp['features'][0]['properties']['postal']
# Out:
# '60644'

# %%
print(results.geojson["features"][4]["properties"]["postal"])
# Out:
# 60644
